# %%
# !pip install numpy
# !pip install matplotlib
# !pip install sklearn
# Out:
# Requirement already satisfied: numpy in c:\users\anh\appdata\local\programs\python\python310\lib\site-packages (1.23.2)
# Requirement already satisfied: matplotlib in c:\users\anh\appdata\local\programs\python\python310\lib\site-packages (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\anh\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\anh\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (4.37.4)
# Requirement already satisfied: numpy>=1.19 in c:\users\anh\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.23.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\anh\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\anh\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (9.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\anh\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\anh\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\anh\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\anh\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: six>=1.5 in c:\users\anh\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: sklearn in c:\users\anh\appdata\local\programs\python\python310\lib\site-packages (0.0)
# Requirement already satisfied: scikit-learn in c:\users\anh\appdata\local\programs\python\python310\lib\site-packages (from sklearn) (1.1.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\anh\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn->sklearn) (3.1.0)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\anh\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn->sklearn) (1.23.2)
# Requirement already satisfied: joblib>=1.0.0 in c:\users\anh\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn->sklearn) (1.2.0)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\anh\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn->sklearn) (1.9.1)

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import numpy

img = plt.imread("a.jpg")
 
width = img.shape[0]
height = img.shape[1]

print(img.shape)
img = img.reshape(width*height,3)


kmeans = KMeans(n_clusters=20).fit(img)

labels = kmeans.predict(img)
clusters = kmeans.cluster_centers_

print(labels)
print(clusters)

img2 = numpy.zeros((width,height,3), dtype=numpy.uint8)

index = 0
for i in range(width):
	for j in range(height):
		label_of_pixel = labels[index]
		img2[i][j] = clusters[label_of_pixel]
		index += 1

plt.imshow(img2)
plt.show()
# Out:
# (1378, 1920, 3)
# [ 1  1  1 ... 11 11  3]
# [[ 20.07277844 128.92603844 185.11125678]
#  [ 24.32111368  72.49199921 114.92349166]
#  [181.14270446 232.00621915 251.72891241]
#  [  3.70574092  33.09903748  62.99623657]
#  [122.89702249 179.70862161 224.4251915 ]
#  [ 58.88276475 110.92136177 157.89737403]
#  [ 79.18878685 134.58394149 182.93926016]
#  [181.68393852 183.01563863 207.11161823]
#  [250.8556572  218.29873997 212.86036075]
#  [243.65026586 238.5878366  242.46330052]
#  [129.04848762  15.66761965  62.23637715]
#  [  9.90477946  16.2898837   49.20017263]
#  [216.46247067 244.34215566 248.70433235]
#  [  6.34131448  78.37780026 131.27233151]
#  [ 38.93329778  90.33010737 134.57306658]
#  [100.18871079 156.15487546 204.16777882]
#  [147.52162184 206.24359538 245.03315215]
#  [ 12.86844858 101.03727212 159.00393761]
#  [  6.27478286  44.49385163  84.39247875]
#  [  9.38640023  60.33092998 102.38614775]]

# %% [markdown]
# ### Comparing to the original image
#
#
# ![a](a.jpg)
